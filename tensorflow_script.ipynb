# %%
import TensorFlowTrainer as TFT

# %%
trainer = TFT.TensorFlowTrainer(training_size=1, batch_size=64, img_patch_size=8)

# %%
trainer.load_data(filter_size=5)
# Out:
# Number of data points per class: c0 = 9097 c1 = 3403

# %%
trainer.train(num_epochs=1, save_predictions=True, restore=False)
# Out:
# Initialized!
# Total number of iterations = 195
#
# Starting epoch  0
# Epoch 0.00
# Minibatch loss: 1.805, learning rate: 0.010000
# Minibatch error: 57.8%
# Model saved in file: ..\tensorflow\model.ckpt
# Running prediction on training set
# [[[ 0.66666669  0.69803923  0.72941178  0.        ]
#   [ 0.68235296  0.70588237  0.73725492  0.        ]
#   [ 0.69411767  0.71764708  0.74901962  0.        ]
#   ...,
#   [ 0.68235296  0.68627453  0.70588237  0.        ]
#   [ 0.69803923  0.69803923  0.71372551  0.        ]
#   [ 0.69411767  0.69411767  0.70980394  0.        ]]
#
#  [[ 0.67843139  0.70980394  0.73725492  0.        ]
#   [ 0.69411767  0.71372551  0.74901962  0.        ]
#   [ 0.69803923  0.71764708  0.75686276  0.        ]
#   ...,
#   [ 0.68235296  0.68235296  0.7019608   0.        ]
#   [ 0.68627453  0.68627453  0.70980394  0.        ]
#   [ 0.68235296  0.67843139  0.69411767  0.        ]]
#
#  [[ 0.67450982  0.69803923  0.72941178  0.        ]
# ...
